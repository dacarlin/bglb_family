# %%
import sys 

import numpy as np 
import seaborn as sns
import pandas

import pyrosetta
from rosetta.protocols import simple_moves, residue_selectors
from rosetta.core import select, chemical 

from Bio.Data import IUPACData

# %%
params = '-beta -extra_res_fa example_input/pnpg.params'
pyrosetta.init(params)
# Out:
# Found rosetta database at: /Users/alex/anaconda3/envs/rose/lib/python3.5/site-packages/pyrosetta-4.0-py3.5.egg/database; using it....
# PyRosetta-4 2016 [Rosetta 2016 unknown:94998f0e5b038b6d8083995a664cb96641cb844b 2017-05-11 15:10:16 -0500] retrieved from: git@github.com:RosettaCommons/main.git
# (C) Copyright Rosetta Commons Member Institutions.
# Created in JHU by Sergey Lyskov and PyRosetta Team.

# %%
! pwd
# Out:
# /Users/alex/Documents/bglb_family/shallow_mutational_scan

# %%
# model all possible mutations for a given position

# %%
pose = pyrosetta.pose_from_file('example_input/native.pdb')
score = pyrosetta.create_score_function('beta') 
wild_type_energy = score(pose)
print('Wild type energy:', wild_type_energy)
# Out:
# Wild type energy: -1447.3390722756833

# %%
def get_pose_energies(pose, score_function):
    energies = pose.energies()
    score_types = score_function.get_nonzero_weighted_scoretypes()
    for pos in range(1, pose.total_residue()+1):
        for st in score_types:
            value = energies.residue_total_energies(pos)[st]
            yield pos, str(st).split('.')[1], value

# %%
muts = pandas.read_csv('../data_sets/speculative_targets.csv')['mutant_name']

# %%
# %%time

def deep_mutational_scan(pose, score_function):
    '''
    input: pose, score function 
    output: pandas DataFrame with per-residue energy features
    '''
    
    length = pose.total_residue()
    for n in range(163, 167): #length+1):
        native = pose.sequence()[n-1]
        for olc, tlc in IUPACData.protein_letters_1to3.items():
            tlc = tlc.upper()
            copy_pose = pose.clone()
            protocol = [
                simple_moves.MutateResidue(n, tlc)
            ]
            for item in protocol: 
                item.apply(copy_pose)
            name = '{}{}{}'.format(native, n, olc)
            for pos, st, value in get_pose_energies(copy_pose, score):
                yield name, pos, st, value
# Out:
# CPU times: user 4 µs, sys: 1 µs, total: 5 µs
# Wall time: 6.91 µs

# %%
columns = ['mutant', 'position', 'score_term', 'value']
df = pandas.DataFrame(deep_mutational_scan(pose, score), columns=columns)

# %%
df.head()
# Out:
#   mutant  position           score_term     value
# 0  N163W         1               fa_atr -4.888219
# 1  N163W         1               fa_rep  0.859524
# 2  N163W         1               fa_sol  2.674700
# 3  N163W         1  fa_intra_atr_xover4 -0.667158
# 4  N163W         1  fa_intra_rep_xover4  1.019409

# %%
g = df.groupby('mutant')

for idx, gdf in g:
    print(idx)
    print(gdf.shape)
    break
# Out:
# I165A
# (11674, 4)

# %%
g.agg(lambda x: x.value)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/alex/anaconda3/envs/rose/lib/python3.5/site-packages/pandas/core/groupby.py in aggregate(self, arg, *args, **kwargs)
#    3207                     result = self._aggregate_multiple_funcs(
# -> 3208                         [arg], _level=_level)
#    3209                     result.columns = Index(
#
# /Users/alex/anaconda3/envs/rose/lib/python3.5/site-packages/pandas/core/base.py in _aggregate_multiple_funcs(self, arg, _level)
#     619
# --> 620         return concat(results, keys=keys, axis=1)
#     621
#
# /Users/alex/anaconda3/envs/rose/lib/python3.5/site-packages/pandas/tools/merge.py in concat(objs, axis, join, join_axes, ignore_index, keys, levels, names, verify_integrity, copy)
#    1450                        verify_integrity=verify_integrity,
# -> 1451                        copy=copy)
#    1452     return op.get_result()
#
# /Users/alex/anaconda3/envs/rose/lib/python3.5/site-packages/pandas/tools/merge.py in __init__(self, objs, axis, join, join_axes, keys, levels, names, ignore_index, verify_integrity, copy)
#    1483         if len(objs) == 0:
# -> 1484             raise ValueError('No objects to concatenate')
#    1485
#
# ValueError: No objects to concatenate
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# /Users/alex/anaconda3/envs/rose/lib/python3.5/site-packages/pandas/core/groupby.py in _aggregate_generic(self, func, *args, **kwargs)
#    3233                 for name, data in self:
# -> 3234                     result[name] = self._try_cast(func(data, *args, **kwargs),
#    3235                                                   data)
#
# TypeError: <lambda>() missing 1 required positional argument: 'y'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-86c2367fa918> in <module>()
# ----> 1 g.agg(lambda x, y: x.value)
#
# /Users/alex/anaconda3/envs/rose/lib/python3.5/site-packages/pandas/core/groupby.py in aggregate(self, arg, *args, **kwargs)
#    3702     @Appender(SelectionMixin._agg_doc)
#    3703     def aggregate(self, arg, *args, **kwargs):
# -> 3704         return super(DataFrameGroupBy, self).aggregate(arg, *args, **kwargs)
#    3705
#    3706     agg = aggregate
#
# /Users/alex/anaconda3/envs/rose/lib/python3.5/site-packages/pandas/core/groupby.py in aggregate(self, arg, *args, **kwargs)
#    3211                         name=self._selected_obj.columns.name)
#    3212                 except:
# -> 3213                     result = self._aggregate_generic(arg, *args, **kwargs)
#    3214
#    3215         if not self.as_index:
#
# /Users/alex/anaconda3/envs/rose/lib/python3.5/site-packages/pandas/core/groupby.py in _aggregate_generic(self, func, *args, **kwargs)
#    3235                                                   data)
#    3236             except Exception:
# -> 3237                 return self._aggregate_item_by_item(func, *args, **kwargs)
#    3238         else:
#    3239             for name in self.indices:
#
# /Users/alex/anaconda3/envs/rose/lib/python3.5/site-packages/pandas/core/groupby.py in _aggregate_item_by_item(self, func, *args, **kwargs)
#    3279             # GH6337
#    3280             if not len(result_columns) and errors is not None:
# -> 3281                 raise errors
#    3282
#    3283         return DataFrame(result, columns=result_columns)
#
# /Users/alex/anaconda3/envs/rose/lib/python3.5/site-packages/pandas/core/groupby.py in _aggregate_item_by_item(self, func, *args, **kwargs)
#    3264                                      grouper=self.grouper)
#    3265                 result[item] = self._try_cast(
# -> 3266                     colg.aggregate(func, *args, **kwargs), data)
#    3267             except ValueError:
#    3268                 cannot_agg.append(item)
#
# /Users/alex/anaconda3/envs/rose/lib/python3.5/site-packages/pandas/core/groupby.py in aggregate(self, func_or_funcs, *args, **kwargs)
#    2666                 return self._python_agg_general(func_or_funcs, *args, **kwargs)
#    2667             except Exception:
# -> 2668                 result = self._aggregate_named(func_or_funcs, *args, **kwargs)
#    2669
#    2670             index = Index(sorted(result), name=self.grouper.names[0])
#
# /Users/alex/anaconda3/envs/rose/lib/python3.5/site-packages/pandas/core/groupby.py in _aggregate_named(self, func, *args, **kwargs)
#    2784         for name, group in self:
#    2785             group.name = name
# -> 2786             output = func(group, *args, **kwargs)
#    2787             if isinstance(output, (Series, Index, np.ndarray)):
#    2788                 raise Exception('Must produce aggregated value')
#
# TypeError: <lambda>() missing 1 required positional argument: 'y'

# %%
df.pivot(columns='score_term', values='value')
# Out:
# score_term  dslf_fa13     fa_atr  fa_dun_dev  fa_dun_rot  fa_dun_semi  \
# 0                 NaN  -4.888219         NaN         NaN          NaN
# 1                 NaN        NaN         NaN         NaN          NaN
# 2                 NaN        NaN         NaN         NaN          NaN
# 3                 NaN        NaN         NaN         NaN          NaN
# 4                 NaN        NaN         NaN         NaN          NaN
# 5                 NaN        NaN         NaN         NaN          NaN
# 6                 NaN        NaN         NaN         NaN          NaN
# 7                 NaN        NaN         NaN         NaN          NaN
# 8                 NaN        NaN         NaN         NaN          NaN
# 9                 NaN        NaN         NaN         NaN          NaN
# 10                NaN        NaN         NaN         NaN          NaN
# 11                NaN        NaN         NaN         NaN          NaN
# 12                NaN        NaN         NaN         NaN          NaN
# 13                NaN        NaN         NaN         NaN          NaN
# 14                NaN        NaN         NaN         NaN          NaN
# 15                NaN        NaN         NaN         NaN          NaN
# 16                NaN        NaN         NaN         NaN          NaN
# 17                0.0        NaN         NaN         NaN          NaN
# 18                NaN        NaN         NaN         NaN          NaN
# 19                NaN        NaN    0.220685         NaN          NaN
# 20                NaN        NaN         NaN    2.016049          NaN
# 21                NaN        NaN         NaN         NaN          0.0
# 22                NaN        NaN         NaN         NaN          NaN
# 23                NaN        NaN         NaN         NaN          NaN
# 24                NaN        NaN         NaN         NaN          NaN
# 25                NaN        NaN         NaN         NaN          NaN
# 26                NaN  -1.676050         NaN         NaN          NaN
# 27                NaN        NaN         NaN         NaN          NaN
# 28                NaN        NaN         NaN         NaN          NaN
# 29                NaN        NaN         NaN         NaN          NaN
# ...               ...        ...         ...         ...          ...
# 933890            NaN        NaN         NaN         NaN          NaN
# 933891            NaN        NaN         NaN         NaN          NaN
# 933892            NaN        NaN         NaN         NaN          NaN
# 933893            NaN        NaN         NaN         NaN          NaN
# 933894            NaN -19.747595         NaN         NaN          NaN
# 933895            NaN        NaN         NaN         NaN          NaN
# 933896            NaN        NaN         NaN         NaN          NaN
# 933897            NaN        NaN         NaN         NaN          NaN
# 933898            NaN        NaN         NaN         NaN          NaN
# 933899            NaN        NaN         NaN         NaN          NaN
# 933900            NaN        NaN         NaN         NaN          NaN
# 933901            NaN        NaN         NaN         NaN          NaN
# 933902            NaN        NaN         NaN         NaN          NaN
# 933903            NaN        NaN         NaN         NaN          NaN
# 933904            NaN        NaN         NaN         NaN          NaN
# 933905            NaN        NaN         NaN         NaN          NaN
# 933906            NaN        NaN         NaN         NaN          NaN
# 933907            NaN        NaN         NaN         NaN          NaN
# 933908            NaN        NaN         NaN         NaN          NaN
# 933909            NaN        NaN         NaN         NaN          NaN
# 933910            NaN        NaN         NaN         NaN          NaN
# 933911            0.0        NaN         NaN         NaN          NaN
# 933912            NaN        NaN         NaN         NaN          NaN
# 933913            NaN        NaN    0.000000         NaN          NaN
# 933914            NaN        NaN         NaN    0.000000          NaN
# 933915            NaN        NaN         NaN         NaN          0.0
# 933916            NaN        NaN         NaN         NaN          NaN
# 933917            NaN        NaN         NaN         NaN          NaN
# 933918            NaN        NaN         NaN         NaN          NaN
# 933919            NaN        NaN         NaN         NaN          NaN
#
# score_term   fa_elec  fa_intra_atr_xover4  fa_intra_elec  fa_intra_rep_xover4  \
# 0                NaN                  NaN            NaN                  NaN
# 1                NaN                  NaN            NaN                  NaN
# 2                NaN                  NaN            NaN                  NaN
# 3                NaN            -0.667158            NaN                  NaN
# 4                NaN                  NaN            NaN             1.019409
# 5                NaN                  NaN            NaN                  NaN
# 6                NaN                  NaN            NaN                  NaN
# 7                NaN                  NaN            NaN                  NaN
# 8                NaN                  NaN            NaN                  NaN
# 9                NaN                  NaN            NaN                  NaN
# 10         -1.662570                  NaN            NaN                  NaN
# 11               NaN                  NaN       0.788484                  NaN
# 12               NaN                  NaN            NaN                  NaN
# 13               NaN                  NaN            NaN                  NaN
# 14               NaN                  NaN            NaN                  NaN
# 15               NaN                  NaN            NaN                  NaN
# 16               NaN                  NaN            NaN                  NaN
# 17               NaN                  NaN            NaN                  NaN
# 18               NaN                  NaN            NaN                  NaN
# 19               NaN                  NaN            NaN                  NaN
# 20               NaN                  NaN            NaN                  NaN
# 21               NaN                  NaN            NaN                  NaN
# 22               NaN                  NaN            NaN                  NaN
# 23               NaN                  NaN            NaN                  NaN
# 24               NaN                  NaN            NaN                  NaN
# 25               NaN                  NaN            NaN                  NaN
# 26               NaN                  NaN            NaN                  NaN
# 27               NaN                  NaN            NaN                  NaN
# 28               NaN                  NaN            NaN                  NaN
# 29               NaN            -0.026876            NaN                  NaN
# ...              ...                  ...            ...                  ...
# 933890           NaN                  NaN            NaN                  NaN
# 933891           NaN                  NaN            NaN                  NaN
# 933892           NaN                  NaN            NaN                  NaN
# 933893           NaN                  NaN            NaN                  NaN
# 933894           NaN                  NaN            NaN                  NaN
# 933895           NaN                  NaN            NaN                  NaN
# 933896           NaN                  NaN            NaN                  NaN
# 933897           NaN            -2.931408            NaN                  NaN
# 933898           NaN                  NaN            NaN             4.051589
# 933899           NaN                  NaN            NaN                  NaN
# 933900           NaN                  NaN            NaN                  NaN
# 933901           NaN                  NaN            NaN                  NaN
# 933902           NaN                  NaN            NaN                  NaN
# 933903           NaN                  NaN            NaN                  NaN
# 933904     -0.931966                  NaN            NaN                  NaN
# 933905           NaN                  NaN       0.372887                  NaN
# 933906           NaN                  NaN            NaN                  NaN
# 933907           NaN                  NaN            NaN                  NaN
# 933908           NaN                  NaN            NaN                  NaN
# 933909           NaN                  NaN            NaN                  NaN
# 933910           NaN                  NaN            NaN                  NaN
# 933911           NaN                  NaN            NaN                  NaN
# 933912           NaN                  NaN            NaN                  NaN
# 933913           NaN                  NaN            NaN                  NaN
# 933914           NaN                  NaN            NaN                  NaN
# 933915           NaN                  NaN            NaN                  NaN
# 933916           NaN                  NaN            NaN                  NaN
# 933917           NaN                  NaN            NaN                  NaN
# 933918           NaN                  NaN            NaN                  NaN
# 933919           NaN                  NaN            NaN                  NaN
#
# score_term  fa_intra_sol_xover4   ...     hxl_tors   lk_ball  lk_ball_bridge  \
# 0                           NaN   ...          NaN       NaN             NaN
# 1                           NaN   ...          NaN       NaN             NaN
# 2                           NaN   ...          NaN       NaN             NaN
# 3                           NaN   ...          NaN       NaN             NaN
# 4                           NaN   ...          NaN       NaN             NaN
# 5                      0.254186   ...          NaN       NaN             NaN
# 6                           NaN   ...          NaN  1.470664             NaN
# 7                           NaN   ...          NaN       NaN             NaN
# 8                           NaN   ...          NaN       NaN        0.000000
# 9                           NaN   ...          NaN       NaN             NaN
# 10                          NaN   ...          NaN       NaN             NaN
# 11                          NaN   ...          NaN       NaN             NaN
# 12                          NaN   ...          NaN       NaN             NaN
# 13                          NaN   ...          NaN       NaN             NaN
# 14                          NaN   ...          NaN       NaN             NaN
# 15                          NaN   ...          NaN       NaN             NaN
# 16                          NaN   ...          NaN       NaN             NaN
# 17                          NaN   ...          NaN       NaN             NaN
# 18                          NaN   ...          NaN       NaN             NaN
# 19                          NaN   ...          NaN       NaN             NaN
# 20                          NaN   ...          NaN       NaN             NaN
# 21                          NaN   ...          NaN       NaN             NaN
# 22                          NaN   ...          NaN       NaN             NaN
# 23                          NaN   ...          0.0       NaN             NaN
# 24                          NaN   ...          NaN       NaN             NaN
# 25                          NaN   ...          NaN       NaN             NaN
# 26                          NaN   ...          NaN       NaN             NaN
# 27                          NaN   ...          NaN       NaN             NaN
# 28                          NaN   ...          NaN       NaN             NaN
# 29                          NaN   ...          NaN       NaN             NaN
# ...                         ...   ...          ...       ...             ...
# 933890                      NaN   ...          NaN       NaN             NaN
# 933891                      NaN   ...          0.0       NaN             NaN
# 933892                      NaN   ...          NaN       NaN             NaN
# 933893                      NaN   ...          NaN       NaN             NaN
# 933894                      NaN   ...          NaN       NaN             NaN
# 933895                      NaN   ...          NaN       NaN             NaN
# 933896                      NaN   ...          NaN       NaN             NaN
# 933897                      NaN   ...          NaN       NaN             NaN
# 933898                      NaN   ...          NaN       NaN             NaN
# 933899                 2.255540   ...          NaN       NaN             NaN
# 933900                      NaN   ...          NaN  5.298614             NaN
# 933901                      NaN   ...          NaN       NaN             NaN
# 933902                      NaN   ...          NaN       NaN        0.082387
# 933903                      NaN   ...          NaN       NaN             NaN
# 933904                      NaN   ...          NaN       NaN             NaN
# 933905                      NaN   ...          NaN       NaN             NaN
# 933906                      NaN   ...          NaN       NaN             NaN
# 933907                      NaN   ...          NaN       NaN             NaN
# 933908                      NaN   ...          NaN       NaN             NaN
# 933909                      NaN   ...          NaN       NaN             NaN
# 933910                      NaN   ...          NaN       NaN             NaN
# 933911                      NaN   ...          NaN       NaN             NaN
# 933912                      NaN   ...          NaN       NaN             NaN
# 933913                      NaN   ...          NaN       NaN             NaN
# 933914                      NaN   ...          NaN       NaN             NaN
# 933915                      NaN   ...          NaN       NaN             NaN
# 933916                      NaN   ...          NaN       NaN             NaN
# 933917                      NaN   ...          0.0       NaN             NaN
# 933918                      NaN   ...          NaN       NaN             NaN
# 933919                      NaN   ...          NaN       NaN             NaN
#
# score_term  lk_ball_bridge_uncpl  lk_ball_iso     omega  p_aa_pp  pro_close  \
# 0                            NaN          NaN       NaN      NaN        NaN
# 1                            NaN          NaN       NaN      NaN        NaN
# 2                            NaN          NaN       NaN      NaN        NaN
# 3                            NaN          NaN       NaN      NaN        NaN
# 4                            NaN          NaN       NaN      NaN        NaN
# 5                            NaN          NaN       NaN      NaN        NaN
# 6                            NaN          NaN       NaN      NaN        NaN
# 7                            NaN     3.269581       NaN      NaN        NaN
# 8                            NaN          NaN       NaN      NaN        NaN
# 9                       0.000000          NaN       NaN      NaN        NaN
# 10                           NaN          NaN       NaN      NaN        NaN
# 11                           NaN          NaN       NaN      NaN        NaN
# 12                           NaN          NaN       NaN      NaN        0.0
# 13                           NaN          NaN       NaN      NaN        NaN
# 14                           NaN          NaN       NaN      NaN        NaN
# 15                           NaN          NaN       NaN      NaN        NaN
# 16                           NaN          NaN       NaN      NaN        NaN
# 17                           NaN          NaN       NaN      NaN        NaN
# 18                           NaN          NaN -0.074848      NaN        NaN
# 19                           NaN          NaN       NaN      NaN        NaN
# 20                           NaN          NaN       NaN      NaN        NaN
# 21                           NaN          NaN       NaN      NaN        NaN
# 22                           NaN          NaN       NaN      0.0        NaN
# 23                           NaN          NaN       NaN      NaN        NaN
# 24                           NaN          NaN       NaN      NaN        NaN
# 25                           NaN          NaN       NaN      NaN        NaN
# 26                           NaN          NaN       NaN      NaN        NaN
# 27                           NaN          NaN       NaN      NaN        NaN
# 28                           NaN          NaN       NaN      NaN        NaN
# 29                           NaN          NaN       NaN      NaN        NaN
# ...                          ...          ...       ...      ...        ...
# 933890                       NaN          NaN       NaN      0.0        NaN
# 933891                       NaN          NaN       NaN      NaN        NaN
# 933892                       NaN          NaN       NaN      NaN        NaN
# 933893                       NaN          NaN       NaN      NaN        NaN
# 933894                       NaN          NaN       NaN      NaN        NaN
# 933895                       NaN          NaN       NaN      NaN        NaN
# 933896                       NaN          NaN       NaN      NaN        NaN
# 933897                       NaN          NaN       NaN      NaN        NaN
# 933898                       NaN          NaN       NaN      NaN        NaN
# 933899                       NaN          NaN       NaN      NaN        NaN
# 933900                       NaN          NaN       NaN      NaN        NaN
# 933901                       NaN    12.775327       NaN      NaN        NaN
# 933902                       NaN          NaN       NaN      NaN        NaN
# 933903                  0.894731          NaN       NaN      NaN        NaN
# 933904                       NaN          NaN       NaN      NaN        NaN
# 933905                       NaN          NaN       NaN      NaN        NaN
# 933906                       NaN          NaN       NaN      NaN        0.0
# 933907                       NaN          NaN       NaN      NaN        NaN
# 933908                       NaN          NaN       NaN      NaN        NaN
# 933909                       NaN          NaN       NaN      NaN        NaN
# 933910                       NaN          NaN       NaN      NaN        NaN
# 933911                       NaN          NaN       NaN      NaN        NaN
# 933912                       NaN          NaN  0.000000      NaN        NaN
# 933913                       NaN          NaN       NaN      NaN        NaN
# 933914                       NaN          NaN       NaN      NaN        NaN
# 933915                       NaN          NaN       NaN      NaN        NaN
# 933916                       NaN          NaN       NaN      0.0        NaN
# 933917                       NaN          NaN       NaN      NaN        NaN
# 933918                       NaN          NaN       NaN      NaN        NaN
# 933919                       NaN          NaN       NaN      NaN        NaN
#
# score_term  rama_prepro      ref
# 0                   NaN      NaN
# 1                   NaN      NaN
# 2                   NaN      NaN
# 3                   NaN      NaN
# 4                   NaN      NaN
# 5                   NaN      NaN
# 6                   NaN      NaN
# 7                   NaN      NaN
# 8                   NaN      NaN
# 9                   NaN      NaN
# 10                  NaN      NaN
# 11                  NaN      NaN
# 12                  NaN      NaN
# 13                  NaN      NaN
# 14                  NaN      NaN
# 15                  NaN      NaN
# 16                  NaN      NaN
# 17                  NaN      NaN
# 18                  NaN      NaN
# 19                  NaN      NaN
# 20                  NaN      NaN
# 21                  NaN      NaN
# 22                  NaN      NaN
# 23                  NaN      NaN
# 24                  NaN  0.60916
# 25             0.000000      NaN
# 26                  NaN      NaN
# 27                  NaN      NaN
# 28                  NaN      NaN
# 29                  NaN      NaN
# ...                 ...      ...
# 933890              NaN      NaN
# 933891              NaN      NaN
# 933892              NaN  1.04020
# 933893        -0.087477      NaN
# 933894              NaN      NaN
# 933895              NaN      NaN
# 933896              NaN      NaN
# 933897              NaN      NaN
# 933898              NaN      NaN
# 933899              NaN      NaN
# 933900              NaN      NaN
# 933901              NaN      NaN
# 933902              NaN      NaN
# 933903              NaN      NaN
# 933904              NaN      NaN
# 933905              NaN      NaN
# 933906              NaN      NaN
# 933907              NaN      NaN
# 933908              NaN      NaN
# 933909              NaN      NaN
# 933910              NaN      NaN
# 933911              NaN      NaN
# 933912              NaN      NaN
# 933913              NaN      NaN
# 933914              NaN      NaN
# 933915              NaN      NaN
# 933916              NaN      NaN
# 933917              NaN      NaN
# 933918              NaN  0.00000
# 933919         0.000000      NaN
#
# [933920 rows x 26 columns]

# %%
# df = pandas.DataFrame( data, columns=fmt.keys() )
# df.index = df.index + 1 
# df.shape

# %%
# seaborn.heatmap(df, cmap='viridis')

# %%
# df.mean( axis=0 ).sort_values()

# %%
# df.mean( axis=1 )

# %%
#df.to_csv( 'repack_mutated_residue_only.csv' )
