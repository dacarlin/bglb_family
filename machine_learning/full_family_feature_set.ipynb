# %%
import pandas

# %%
! rsync -avz ca:/share/work/alex/bglb_family/completed_pipeline/results.h5 .
# Out:
# /home/carlin/.bashrc: line 3: bind: warning: line editing not enabled
# receiving file list ... done
# results.h5
#
# sent 38 bytes  received 340546 bytes  227056.00 bytes/sec
# total size is 2497061  speedup is 7.33

# %%
df = pandas.read_hdf('results.h5')
df.sample(5)
# Out:
#               total_score  fa_rep  hbond_sc  all_cst  tot_pstat_pm  \
# SDJGI_67         -3215.55  419.25    -68.85      0.0          0.69
# R4SWC3_AMYOR     -3073.11  333.85    -82.02      0.0          0.65
# A8FIW6_BACP2     -3111.46  682.29    -89.96      0.0          0.66
# SDJGI_163        -3097.76  414.78    -80.53      0.0          0.70
# Q04H61_OENOB     -3317.79  551.28    -88.03      0.0          0.66
#
#               tot_nlpstat_pm  tot_burunsat_pm  tot_hbond_pm  tot_NLconts_pm  \
# SDJGI_67                0.69            167.0         453.0           274.0
# R4SWC3_AMYOR            0.63            134.0         433.0           256.0
# A8FIW6_BACP2            0.63            170.0         472.0           274.0
# SDJGI_163               0.67            149.0         462.0           251.0
# Q04H61_OENOB            0.65            159.0         459.0           286.0
#
#               tot_nlsurfaceE_pm       ...          SR_5  SR_5_total_score  \
# ...
