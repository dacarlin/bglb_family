# %%
import pandas

df = pandas.read_csv('score.sc', sep='\s+', header=1)
df.sort_values('total_score').head()
# Out:
#     SCORE:  total_score  atom_pair_constraint  cart_bonded  dslf_fa13  \
# 64  SCORE:     9073.354              9307.795      293.577        0.0
# 61  SCORE:     9147.599              9307.310      390.228        0.0
# 84  SCORE:     9153.434              9315.571      367.606        0.0
# 50  SCORE:     9156.205              9317.043      347.379        0.0
# 49  SCORE:     9158.013              9313.074      351.005        0.0
#
#       fa_atr  fa_dun_dev  fa_dun_rot  fa_dun_semi  fa_elec     ...       \
# 64 -2507.368      41.824     157.677      449.088 -214.189     ...
# 61 -2564.796      42.507     170.778      452.243 -239.790     ...
# 84 -2529.265      41.718     176.805      447.357 -228.501     ...
# 50 -2514.179      44.710     176.887      451.877 -229.309     ...
# 49 -2547.063      44.364     174.152      452.983 -235.409     ...
#
#     hxl_tors  lk_ball  lk_ball_bridge  lk_ball_bridge_uncpl  lk_ball_iso  \
# ...
