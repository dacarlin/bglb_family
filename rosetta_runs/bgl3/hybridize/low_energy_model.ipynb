# %%
import pandas 
df = pandas.read_csv( 'score.sc', sep='\s+', header=1 )
df.sort_values( 'total_score' ).head( 10 )
# Out:
#     SCORE:  total_score  atom_pair_constraint  cart_bonded  dslf_fa13  \
# 6   SCORE:     7830.637              8934.761      374.155        0.0
# 7   SCORE:     7832.076              8938.830      375.366        0.0
# 1   SCORE:     7867.688              8936.638      383.321        0.0
# 0   SCORE:     7888.015              8939.606      397.936        0.0
# 8   SCORE:     7905.465              8937.850      416.586        0.0
# 10  SCORE:     7927.668              8945.105      416.306        0.0
# 4   SCORE:     7945.599              8951.142      440.792        0.0
# 5   SCORE:     7952.189              8967.441      432.018        0.0
# 11  SCORE:     7972.450              8957.207      496.715        0.0
# 9   SCORE:     7983.430              8937.380      512.148        0.0
#
#       fa_atr  fa_dun_dev  fa_dun_rot  fa_dun_semi   fa_elec     ...       \
# 6  -2901.067      40.337     152.561      330.891  -978.349     ...
# ...

# %%
! open S_0007.pdb /Users/alex/Documents/bagel-foldit/bglb.pdb

# %%
# in pymol: 
# super bglb, S_0007 
# extract ligand to object 
# save molecule as ../tss_docking/lig.pdb

# %%
! ( grep ^ATOM S_0007.pdb && grep ^HETATM ../tss_docking/lig.pdb ) > ../tss_docking/bgl3_wlig.pdb
